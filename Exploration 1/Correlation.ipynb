# %%
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('final.csv')
df
# Out:
#           ID        DATE     Month Day of week Crash Time  Crash Severity  \
# 0          1    1/1/2002   January     Tuesday      12:00               0
# 1          2    1/2/2002   January   Wednesday       4:26               1
# 2          3    1/2/2002   January   Wednesday       5:10               1
# 3          4    1/2/2002   January   Wednesday       7:20               2
# 4          5    1/2/2002   January   Wednesday      11:10               0
# ...      ...         ...       ...         ...        ...             ...
# 21488  21489  11/30/2021  November     Tuesday      14:49               2
# 21489  21490  11/30/2021  November     Tuesday      16:01               2
# 21490  21491  11/30/2021  November     Tuesday      23:27               2
# 21491  21492   1/23/2022   January      Sunday       9:04               1
# 21492  21493   1/23/2022   January      Sunday      14:57               1
#
#        Number of Vehicles  Total Nonfatal Injuries  Total Fatal Injuries  \
# ...

# %%
df2=df.drop(columns=['ID','Longtitute','Latitute','Total Nonfatal Injuries','Total Fatal Injuries'])

# %%
df2.corr()
# Out:
#                     Crash Severity  Number of Vehicles      PRCP      SNOW  \
# Crash Severity            1.000000            0.039385 -0.013775 -0.028205
# Number of Vehicles        0.039385            1.000000 -0.023756 -0.026991
# PRCP                     -0.013775           -0.023756  1.000000  0.219947
# SNOW                     -0.028205           -0.026991  0.219947  1.000000
# TMAX                      0.044964            0.033499 -0.060879 -0.275662
# TMIN                      0.039077            0.019255  0.064935 -0.234910
# Ice                      -0.037917           -0.029833 -0.084863  0.249411
#
#                         TMAX      TMIN       Ice
# Crash Severity      0.044964  0.039077 -0.037917
# Number of Vehicles  0.033499  0.019255 -0.029833
# PRCP               -0.060879  0.064935 -0.084863
# SNOW               -0.275662 -0.234910  0.249411
# TMAX                1.000000  0.916288 -0.771188
# TMIN                0.916288  1.000000 -0.820134
# ...

# %%
sn.heatmap(corrMatrix, annot=True)
plt.show()
