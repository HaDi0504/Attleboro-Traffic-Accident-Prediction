# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random
import datetime

# %%
Cr=pd.read_csv('final.csv')

# %%
Cr.head()
# Out:
#    ID      DATE Crash Time                       Crash Severity  \
# 0   1  1/1/2002   12:00 PM                         Not Reported
# 1   2  1/2/2002    4:26 AM  Property damage only (none injured)
# 2   3  1/2/2002    5:10 AM  Property damage only (none injured)
# 3   4  1/2/2002    7:20 AM                     Non-fatal injury
# 4   5  1/2/2002   11:10 AM                         Not Reported
#
#         Maximum Injury Severity Reported  Number of Vehicles  \
# 0                           Not reported                   2
# 1                              No injury                   2
# 2                              No injury                   1
# 3  Non-fatal injury - Non-incapacitating                   1
# 4                           Not reported                   1
#
#    Total Nonfatal Injuries  Total Fatal Injuries   Manner of Collision  \
# 0                        0                     0              Rear-end
# ...

# %%
Crash.columns
# Out:
# Index(['ID', 'DATE', 'Crash Time', 'Crash Severity',
#        'Maximum Injury Severity Reported', 'Number of Vehicles',
#        'Total Nonfatal Injuries', 'Total Fatal Injuries',
#        'Manner of Collision', 'Vehicle Action Prior to Crash',
#        'Vehicle Travel Directions', 'Road Surface Condition', 'Ambient Light',
#        'Weather Condition', 'X Cooordinate', 'Y Cooordinate', 'STATION',
#        'NAME', 'PRCP', 'SNOW', 'TMAX', 'TMIN', 'Ice', 'Longtitute',
#        'Latitute'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Accident'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...
