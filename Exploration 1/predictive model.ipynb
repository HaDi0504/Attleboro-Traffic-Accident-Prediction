# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random
import datetime

# %%
df500clust = pd.read_csv("final.csv")

# %%
pima.head()
# Out:
#    ID      DATE Crash Time                       Crash Severity  \
# 0   1  1/1/2002   12:00 PM                         Not Reported
# 1   2  1/2/2002    4:26 AM  Property damage only (none injured)
# 2   3  1/2/2002    5:10 AM  Property damage only (none injured)
# 3   4  1/2/2002    7:20 AM                     Non-fatal injury
# 4   5  1/2/2002   11:10 AM                         Not Reported
#
#         Maximum Injury Severity Reported  Number of Vehicles  \
# 0                           Not reported                   2
# 1                              No injury                   2
# 2                              No injury                   1
# 3  Non-fatal injury - Non-incapacitating                   1
# 4                           Not reported                   1
#
#    Total Nonfatal Injuries  Total Fatal Injuries   Manner of Collision  \
# 0                        0                     0              Rear-end
# 1                        0                     0                 Angle
# 2                        0                     0                 Angle
# 3                        1                     0  Single vehicle crash
# 4                        0                     0  Single vehicle crash
#
#                       Vehicle Action Prior to Crash  ... Y Cooordinate  \
# 0  V1: Turning left / V2: Travelling straight ahead  ...   855385.4998
# 1  V1: Turning left / V2: Travelling straight ahead  ...   853612.5626
# 2                 V1: Slowing or stopped in traffic  ...   855354.6877
# 3                     V1: Travelling straight ahead  ...   853458.8080
# 4                                       V1: Backing  ...   854228.4346
#
#        STATION                      NAME PRCP  SNOW  TMAX TMIN   Ice  \
# 0  USC00198368  NWS BOSTON NORTON, MA US  0.0   0.0    36   13  True
# 1  USC00198368  NWS BOSTON NORTON, MA US  0.0   0.0    39   19  True
# 2  USC00198368  NWS BOSTON NORTON, MA US  0.0   0.0    39   19  True
# 3  USC00198368  NWS BOSTON NORTON, MA US  0.0   0.0    39   19  True
# 4  USC00198368  NWS BOSTON NORTON, MA US  0.0   0.0    39   19  True
#
#    Longtitute   Latitute
# 0   41.948610 -71.277587
# 1   41.932683 -71.296220
# 2   41.948334 -71.277947
# 3   41.931229 -71.260316
# 4   41.938218 -71.291080
#
# [5 rows x 25 columns]

# %%
pima.columns
# Out:
# Index(['ID', 'DATE', 'Crash Time', 'Crash Severity',
#        'Maximum Injury Severity Reported', 'Number of Vehicles',
#        'Total Nonfatal Injuries', 'Total Fatal Injuries',
#        'Manner of Collision', 'Vehicle Action Prior to Crash',
#        'Vehicle Travel Directions', 'Road Surface Condition', 'Ambient Light',
#        'Weather Condition', 'X Cooordinate', 'Y Cooordinate', 'STATION',
#        'NAME', 'PRCP', 'SNOW', 'TMAX', 'TMIN', 'Ice', 'Longtitute',
#        'Latitute'],
#       dtype='object')

# %%
df500clust.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21493 entries, 0 to 21492
# Data columns (total 25 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   ID                                21493 non-null  int64
#  1   DATE                              21493 non-null  object
#  2   Crash Time                        21493 non-null  object
#  3   Crash Severity                    21493 non-null  object
#  4   Maximum Injury Severity Reported  21493 non-null  object
#  5   Number of Vehicles                21493 non-null  int64
#  6   Total Nonfatal Injuries           21493 non-null  int64
#  7   Total Fatal Injuries              21493 non-null  int64
#  8   Manner of Collision               21493 non-null  object
#  9   Vehicle Action Prior to Crash     21493 non-null  object
#  10  Vehicle Travel Directions         21493 non-null  object
#  11  Road Surface Condition            21493 non-null  object
#  12  Ambient Light                     21493 non-null  object
#  13  Weather Condition                 21493 non-null  object
#  14  X Cooordinate                     21493 non-null  float64
#  15  Y Cooordinate                     21493 non-null  float64
#  16  STATION                           21493 non-null  object
#  17  NAME                              21493 non-null  object
#  18  PRCP                              21493 non-null  float64
#  19  SNOW                              21493 non-null  float64
#  20  TMAX                              21493 non-null  int64
#  21  TMIN                              21493 non-null  int64
#  22  Ice                               21493 non-null  bool
#  23  Longtitute                        21493 non-null  float64
#  24  Latitute                          21493 non-null  float64
# dtypes: bool(1), float64(6), int64(6), object(12)
# memory usage: 4.0+ MB

# %%
#create all data to be fed to logistics regression
df_nonacc_n_acc = pd.DataFrame(columns=[
    'DATE', 'Crash Time', 'Crash Severity',
       'Maximum Injury Severity Reported', 'Number of Vehicles',
       'Total Nonfatal Injuries', 'Total Fatal Injuries',
       'Manner of Collision', 'Vehicle Action Prior to Crash',
       'Vehicle Travel Directions', 'Road Surface Condition', 'Ambient Light',
       'Weather Condition', 'X Cooordinate', 'Y Cooordinate', 'STATION',
       'PRCP', 'SNOW', 'TMAX', 'TMIN', 'Ice', 'Longtitute',
       'Latitute'])
